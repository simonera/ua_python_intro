# %% [markdown]
# <a href="https://colab.research.google.com/github/simonera/ua_python_intro/blob/main/05_1_Data_Visualization_with_Python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Visualization with Python
#
# ***
#
# ### Introduction
#
# There are many options for doing [Data Visualization](https://en.wikipedia.org/wiki/Data_visualization) in Python. [Matplotlib](https://en.wikipedia.org/wiki/Matplotlib) visualization library is among the most widely used plotting library and first choice for many data scientists and machine learning researchers and practitioners.
#
# [Matplotlib](https://matplotlib.org/stable/gallery/index.html) includes the Pyplot module which provides a MATLAB-like interface. Matplotlib is designed to be as usable as [MATLAB](https://en.wikipedia.org/wiki/MATLAB), with the ability to use Python, and the advantage of being free and open-source.
#
# Among all visualization libraries for Python, we enlist some of the most popular:
#
# * [**Altair**](https://altair-viz.github.io). Altair is a declarative statistical visualization library for Python, based on [Vega](https://vega.github.io/vega/) and [Vega-Lite](https://vega.github.io/vega-lite/).
# * [**Bokeh**](https://bokeh.org). Bokeh is a Python library for creating interactive visualizations for modern web browsers.
# * [**Ggplot**](https://github.com/yhat/ggpy). It is a Python implementation of the grammar of graphics.
# * [**Matplotlib**](https://matplotlib.org/stable/index.html). Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# * [**Plotly**](https://plotly.com/python/). Plotly's Python graphing library makes interactive, publication-quality graphs.
# * [**Plotnine**](https://plotnine.readthedocs.io/en/stable/index.html). plotnine is an implementation of a grammar of graphics in Python, it is based on [ggplot2](https://ggplot2.tidyverse.org) used in R programming language.
# * [**Seaborn**](https://seaborn.pydata.org). Seaborn is a Python data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# ***
#
# ### Matplotlib
#
# Let's start with some Matplotlib properties and examples.
#
# Matplotlib is a “low-level” plotting library, which means that it can be customized to fit out purposes.

# %%
# We load the libraries into running memory

import pandas as pd
import numpy as np

# Visualization libraries

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import plotly.express as px

import plotnine as p9

# %% [markdown]
# ### Object Oriented Plotting
#
# There are essentially **two** ways to use Matplotlib:
#
# * Explicitly create _Figures_ and _Axes_, and call methods on them (the "object-oriented (OO) style").
# * Rely on _pyplot_ to automatically create and manage the _Figures_ and _Axes_, and use pyplot functions for plotting.

# %%
# 1st. Method: Object Oriented Style (OO-style)
# this method will use the "ax." variable seen below

x = np.linspace(0, 5, 100 )  # Sample data, 100 points between 0 and 5.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(10, 6))

ax.grid(True) # Add a grid

ax.plot(x, np.sin(x), label='Sine function $\sin(x)$')  # Plot some data on the axes. Can use LaTeX notation.
ax.plot(x, x, label='linear $x$')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic $x^{3}$')  # ... and some more.
ax.plot(x, x-x**3/6.0, linestyle='dashed', label='$x - x^{3} / 6$')

ax.set_xlim([0, np.pi/2]) # We select limits for plotting -- notice: pi is 3.14159265359 (interesting choice...)
ax.set_ylim([0, 1.5])

# Optional: We can define where and what the xtics can be
ax.set_xticks([0, 0.125*np.pi, 0.25*np.pi, 0.375*np.pi, np.pi/2]) # values
ax.set_xticklabels(['$0$', '$\pi/8$','$\pi/4$','$3 \pi/8$','$\pi/2$']) # labels; this is latex notation

ax.set_xlabel('$x$')  # Add an x-label to the axes.
ax.set_ylabel('$y = f(x)$')  # Add a y-label to the axes.
ax.set_title("Simple function plots")  # Add a title to the axes.

ax.legend();  # Add a legend.

# %%
# Method 2: Using pyplot

x = np.linspace(0, 5, 100)  # Sample data.

plt.figure(figsize=(10, 6))
plt.grid(True) # Add a grid

plt.plot(x, np.sin(x), label='Sine function $\sin(x)$')  # Plot some data. Can use LaTeX notation.
plt.plot(x, x, label='linear $x$')  # etc.
plt.plot(x, x**3, label='cubic $x^{3}$')
plt.plot(x, x-x**3/6.0, linestyle='dashed', label='$x - x^{3} / 6$')

plt.xlim([0, np.pi/2.0 ]) # We select limits for plotting
plt.ylim([0, 1.5])

# Optional: We can define where and what the xtics can be
plt.xticks([0, 0.125*np.pi, 0.25*np.pi, 0.375*np.pi, np.pi/2], # different as in first method above
           ['$0$', '$\pi/8$','$\pi/4$','$3 \pi/8$','$\pi/2$'])

plt.xlabel('$x$')
plt.ylabel('$y = f(x)$')
plt.title("Simple function plots")
plt.legend();

# %% [markdown]
# ## Multiple plots example
#
# [More information on subplots](https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html)

# %%
# Create some fake data for next 2 examples.
x1 = np.linspace(0.0, 5.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
x2 = np.linspace(0.0, 2.0)
y2 = np.cos(2 * np.pi * x2)

# %%
# Method 1: Axes method

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 6)) # 2 = 2 plots, 1 = 1 sub-title

fig.suptitle('Making multiple plots') # General title

# First plot
ax1.grid(True) # Add a grid to first plot
ax1.plot(x1, y1, 'o-', label='$\cos(2 \pi x) \exp(-x)$') # plotting x1 and y1, o- uses circles and labels; note: this label doesn't work
# it works now that we added ax1.legend()
ax1.set_ylabel('Damped oscillation')
ax1.legend()

# Second plot
ax2.grid(True) # Add a grid to second plot
ax2.plot(x2, y2, '.-') # plotting x2 and y2, uses dashes
ax2.set_xlabel('time (s)')
ax2.set_ylabel('Undamped')

plt.show()

# %%
# Method 2: Using Pyplot.

plt.figure(figsize=(10, 6))

# First plot
plt.subplot(2, 1, 1)
plt.grid(True)
plt.plot(x1, y1, 'o-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

# Second plot
plt.subplot(2, 1, 2)
plt.grid(True)
plt.plot(x2, y2, '.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.show()

# %% [markdown]
# ## 3D Plots

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from mpl_toolkits.mplot3d.axes3d import get_test_data


# set up a figure 3 times as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.333))

# =============
# First subplot
# =============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')

# plot a 3D surface like in the example mplot3d/surface3d_demo
X = np.arange(-5, 5, 0.125)
Y = np.arange(-5, 5, 0.125)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=10)

# ==============
# Second subplot
# ==============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# plot a 3D wireframe like in the example mplot3d/wire3d_demo
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

plt.show()

# %% [markdown]
# ## Penguins dataset.
#
# #### Palmer Archipelago (Antarctica) penguin data
#
# Data were collected and made available by Dr. Kristen Gorman and the Palmer Station, Antarctica LTER, a member of the Long Term Ecological Research Network.
#
# Gorman KB, Williams TD, Fraser WR (2014) Ecological Sexual Dimorphism and Environmental Variability within a Community of Antarctic Penguins (Genus Pygoscelis). PLoS ONE 9(3): e90081. doi:10.1371/journal.pone.0090081
#
# penguins_size.csv file
#
# Contains variables:
#
# * species: penguin species (Chinstrap, Adélie, or Gentoo)
# * culmen_length_mm: culmen length (mm)
# culmen_depth_mm: culmen depth (mm)
# * flipper_length_mm: flipper length (mm)
# * body_mass_g: body mass (g)
# * island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# * sex: penguin sex

# %% [markdown]
# ![lter_penguins.png](data:image/png;base64,...)

# %%
# We load the libraries into running memory

import pandas as pd
import numpy as np

# Visualization libraries

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import plotly.express as px

import plotnine as p9

# %%
# Read the penguins size dataset

filename = "https://raw.githubusercontent.com/clizarraga-UAD7/Datasets/main/penguins/penguins_size.csv"

df = pd.read_csv(filename)

df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# General information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# After some strange plots, discovered that there was one extra value for sex.
df['sex'].value_counts().unique() # 168 rows have a given value, 165 a second one, and 1 a third one
# Out:
# array([168, 165,   1])

# %%
# Define a new dataframe, eliminating the unknown value
df1 = df.copy().dropna() # drop missing
df1 = df1[df.sex!='.'] # select not equal to dot
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   culmen_length_mm   333 non-null    float64
#  3   culmen_depth_mm    333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB
# <ipython-input-6-d7415addfc23>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ## Figures and Subplots

# %%
# Brief Matplotlib premier
# Create an empty figure object
fig = plt.figure()
# Add some subplots 2 cols x 2 rows = 4 subplots
ax1 = fig.add_subplot(2,2,1) # 1 is top left
ax2 = fig.add_subplot(2,2,2) # 2 is top right
ax3 = fig.add_subplot(2,2,3) # 3 is bottom left

# %%
# Add some content to the plots

# Create an empty figure object
fig = plt.figure(figsize=(12, 8))
# Add some subplots 2 cols x 2 rows = 4 subplots, but plotting only 3
ax1 = fig.add_subplot(2,2,1) # First subplot of row 1
ax2 = fig.add_subplot(2,2,2) # Second subplot of row 1
ax3 = fig.add_subplot(2,2,3) # Third subplot, now on row 2

# _ = ax1.hist(df1['body_mass_g'], bins=20, color = 'tab:blue', alpha = 0.4)
# What does _= do? ChatGPT says: In Python, _ is typically used as a variable
# name when you want to store a value but you don't intend to use that value
# further in your code. It's a convention to indicate that the value is
# meant to be ignored or discarded.

# the graph runs also without it
ax1.hist(df1['body_mass_g'], bins=20, color = 'tab:blue', alpha = 0.4)
ax2.scatter(x = df1['culmen_length_mm'], y = df1['culmen_depth_mm'], color = 'tab:orange', marker = "v", )
ax3.boxplot(df1['flipper_length_mm']);

# %% [markdown]
# ### Adding Ticks, Labels and Legends

# %%
# Add some ticks, labels and legends to the plots

# Create an empty figure object
fig = plt.figure(figsize=(12, 8), constrained_layout=False, tight_layout=False)
# Add some subplots 2 cols x 2 rows = 4 subplots, but plotting only 3
ax1 = fig.add_subplot(2,2,1) # First subplot of row 1
ax2 = fig.add_subplot(2,2,2) # Second subplot of row 1
ax3 = fig.add_subplot(2,2,3) # Third subplot, now on row 2

# Add subplots
_ = ax1.hist(df1['body_mass_g'], bins=20, color = 'tab:blue', alpha = 0.4)
ax2.scatter(x = df1['culmen_length_mm'], y = df1['culmen_depth_mm'], color = 'tab:orange', marker = "v", )
ax3.boxplot(df1['flipper_length_mm'])

# Work on details of 1st. plot
ax1.set_xticks([3000, 4000, 5000, 6000])
ax1.set_xticklabels(['3.0', '4.0', '5.0', '6.0'], rotation=30, fontsize='small')
ax1.set_title('Penguins mass distribution (kg)')

# Work on details of 2nd. plot
ax2.set_xticks([30, 40, 50, 60])
ax2.set_xticklabels(['3.0', '4.0', '5.0', '6.0'], rotation=30, fontsize='small')
ax2.set_xlabel('Culmen length (cm)')
ax2.set_yticks([10, 15, 20, 25])
ax2.set_yticklabels(['1.0', '1.5', '2.0', '2.5'], fontsize='small')
ax2.set_ylabel('Culmen depth (cm)')
ax2.set_title('Culmen Depth vs. Length (cm)')

# Work on details of 3rd. plot
ax3.set_xlabel('')
ax3.set_yticks([160, 180, 200, 220, 240])
ax3.set_yticklabels(['16.0', '18.0', '20.0', '22.0', '24.0'], fontsize='small')
ax3.set_ylabel('Flipper length (cm)')
ax3.set_title('Flipper Lenght variability')

# Optional
# Setting width and height space between subplots and general plot title
plt.subplots_adjust(left=0.13, right=0.93, top=1.0, bottom= 0.3, wspace= 0.3, hspace=0.3)
plt.suptitle('Antartica Penguins Dataset', y=1.08, fontsize=14, fontweight='bold');
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py:27: UserWarning: The Figure parameters 'tight_layout' and 'constrained_layout' cannot be used together. Please use 'layout' parameter

# %% [markdown]
# ## Scatter plots

# %%
import matplotlib.patches

plt.figure(figsize=(10,6))

levels, categories = pd.factorize(df['species'])
colors = [plt.cm.tab10(i) for i in levels] # using the "tab10" colormap
handles = [matplotlib.patches.Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

plt.scatter(df['body_mass_g'], df['flipper_length_mm'], c=colors)
plt.gca().set(xlabel='mass (g)', ylabel='Flipper Length', title='Penguin Mass vs Flipper Length')
plt.legend(handles=handles, title='Species');

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.culmen_length_mm.head()
# Out:
# 0    39.1
# 1    39.5
# 2    40.3
# 3     NaN
# 4    36.7
# Name: culmen_length_mm, dtype: float64

# %% [markdown]
# ## Correlation Map

# %%
# Using Pandas color table style

corr = df.corr()
corr.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_db0bc_row0_col0, #T_db0bc_row1_col1, #T_db0bc_row2_col2, #T_db0bc_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_db0bc_row0_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_db0bc_row0_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_db0bc_row0_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_db0bc_row1_col0, #T_db0bc_row1_col2, #T_db0bc_row1_col3, #T_db0bc_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_db0bc_row2_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_db0bc_row2_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_db0bc_row3_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_db0bc_row3_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_db0bc_row3_col2 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db0bc_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >culmen_length_mm</th>
#       <th class="col_heading level0 col1" >culmen_depth_mm</th>
#       <th class="col_heading level0 col2" >flipper_length_mm</th>
#       <th class="col_heading level0 col3" >body_mass_g</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0bc_level0_row0" class="row_heading level0 row0" >culmen_length_mm</th>
#       <td id="T_db0bc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_db0bc_row0_col1" class="data row0 col1" >-0.235053</td>
#       <td id="T_db0bc_row0_col2" class="data row0 col2" >0.656181</td>
#       <td id="T_db0bc_row0_col3" class="data row0 col3" >0.595110</td>
#     </tr>
#     <tr>
#       <th id="T_db0bc_level0_row1" class="row_heading level0 row1" >culmen_depth_mm</th>
#       <td id="T_db0bc_row1_col0" class="data row1 col0" >-0.235053</td>
#       <td id="T_db0bc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_db0bc_row1_col2" class="data row1 col2" >-0.583851</td>
#       <td id="T_db0bc_row1_col3" class="data row1 col3" >-0.471916</td>
#     </tr>
#     <tr>
#       <th id="T_db0bc_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_db0bc_row2_col0" class="data row2 col0" >0.656181</td>
#       <td id="T_db0bc_row2_col1" class="data row2 col1" >-0.583851</td>
#       <td id="T_db0bc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_db0bc_row2_col3" class="data row2 col3" >0.871202</td>
#     </tr>
#     <tr>
#       <th id="T_db0bc_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_db0bc_row3_col0" class="data row3 col0" >0.595110</td>
#       <td id="T_db0bc_row3_col1" class="data row3 col1" >-0.471916</td>
#       <td id="T_db0bc_row3_col2" class="data row3 col2" >0.871202</td>
#       <td id="T_db0bc_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Matplotlib Correlation Heatmap

result = df.select_dtypes(include='number')
plt.imshow(result.corr(), cmap='Blues', interpolation='nearest')
plt.show()

# Not a good result. Needs more elaborated solution

# %%
## Seaborn Correlation Map

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm");

# %%
# Seaborn Masked correlation heatmap
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
  f, ax = plt.subplots(figsize=(8, 8))
  ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True, cmap='Blues')

# %%
# Plotly Express heatmap

#fig = px.density_heatmap(df.corr().values, text_auto=True)
fig = px.density_heatmap(df, x="body_mass_g", y="flipper_length_mm", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb56dbc3-8285-4fac-bbe0-07ea8b5eb9c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb56dbc3-8285-4fac-bbe0-07ea8b5eb9c2")) {                    Plotly.newPlot(                        "bb56dbc3-8285-4fac-bbe0-07ea8b5eb9c2",                        [{"coloraxis":"coloraxis","hovertemplate":"body_mass_g=%{x}<br>flipper_length_mm=%{y}<br>count=%{z}<extra></extra>","name":"","x":[3750.0,3800.0,3250.0,null,3450.0,3650.0,3625.0,4675.0,3475.0,4250.0,3300.0,3700.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3400.0,3600.0,3800.0,3950.0,3800.0,3800.0,3550.0,3200.0,3150.0,3950.0,3250.0,3900.0,3300.0,3900.0,3325.0,4150.0,3950.0,3550.0,3300.0,4650.0,3150.0,3900.0,3100.0,4400.0,3000.0,4600.0,3425.0,2975.0,3450.0,4150.0,3500.0,4300.0,3450.0,4050.0,2900.0,3700.0,3550.0,3800.0,2850.0,3750.0,3150.0,4400.0,3600.0,4050.0,2850.0,3950.0,3350.0,4100.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,3350.0,3550.0,3800.0,3500.0,3950.0,3600.0,3550.0,4300.0,3400.0,4450.0,3300.0,4300.0,3700.0,4350.0,2900.0,4100.0,3725.0,4725.0,3075.0,4250.0,2925.0,3550.0,3750.0,3900.0,3175.0,4775.0,3825.0,4600.0,3200.0,4275.0,3900.0,4075.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0,3500.0,4475.0,3425.0,3900.0,3175.0,3975.0,3400.0,4250.0,3400.0,3475.0,3050.0,3725.0,3000.0,3650.0,4250.0,3475.0,3450.0,3750.0,3700.0,4000.0,3500.0,3900.0,3650.0,3525.0,3725.0,3950.0,3250.0,3750.0,4150.0,3700.0,3800.0,3775.0,3700.0,4050.0,3575.0,4050.0,3300.0,3700.0,3450.0,4400.0,3600.0,3400.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,3700.0,4550.0,3200.0,4300.0,3350.0,4100.0,3600.0,3900.0,3850.0,4800.0,2700.0,4500.0,3950.0,3650.0,3550.0,3500.0,3675.0,4450.0,3400.0,4300.0,3250.0,3675.0,3325.0,3950.0,3600.0,4050.0,3350.0,3450.0,3250.0,4050.0,3800.0,3525.0,3950.0,3650.0,3650.0,4000.0,3400.0,3775.0,4100.0,3775.0,4500.0,5700.0,4450.0,5700.0,5400.0,4550.0,4800.0,5200.0,4400.0,5150.0,4650.0,5550.0,4650.0,5850.0,4200.0,5850.0,4150.0,6300.0,4800.0,5350.0,5700.0,5000.0,4400.0,5050.0,5000.0,5100.0,4100.0,5650.0,4600.0,5550.0,5250.0,4700.0,5050.0,6050.0,5150.0,5400.0,4950.0,5250.0,4350.0,5350.0,3950.0,5700.0,4300.0,4750.0,5550.0,4900.0,4200.0,5400.0,5100.0,5300.0,4850.0,5300.0,4400.0,5000.0,4900.0,5050.0,4300.0,5000.0,4450.0,5550.0,4200.0,5300.0,4400.0,5650.0,4700.0,5700.0,4650.0,5800.0,4700.0,5550.0,4750.0,5000.0,5100.0,5200.0,4700.0,5800.0,4600.0,6000.0,4750.0,5950.0,4625.0,5450.0,4725.0,5350.0,4750.0,5600.0,4600.0,5300.0,4875.0,5550.0,4950.0,5400.0,4750.0,5650.0,4850.0,5200.0,4925.0,4875.0,4625.0,5250.0,4850.0,5600.0,4975.0,5500.0,4725.0,5500.0,4700.0,5500.0,4575.0,5500.0,5000.0,5950.0,4650.0,5500.0,4375.0,5850.0,4875.0,6000.0,4925.0,null,4850.0,5750.0,5200.0,5400.0],"xaxis":"x","xbingroup":"x","y":[181.0,186.0,195.0,null,193.0,190.0,181.0,195.0,193.0,190.0,186.0,180.0,182.0,191.0,198.0,185.0,195.0,197.0,184.0,194.0,174.0,180.0,189.0,185.0,180.0,187.0,183.0,187.0,172.0,180.0,178.0,178.0,188.0,184.0,195.0,196.0,190.0,180.0,181.0,184.0,182.0,195.0,186.0,196.0,185.0,190.0,182.0,179.0,190.0,191.0,186.0,188.0,190.0,200.0,187.0,191.0,186.0,193.0,181.0,194.0,185.0,195.0,185.0,192.0,184.0,192.0,195.0,188.0,190.0,198.0,190.0,190.0,196.0,197.0,190.0,195.0,191.0,184.0,187.0,195.0,189.0,196.0,187.0,193.0,191.0,194.0,190.0,189.0,189.0,190.0,202.0,205.0,185.0,186.0,187.0,208.0,190.0,196.0,178.0,192.0,192.0,203.0,183.0,190.0,193.0,184.0,199.0,190.0,181.0,197.0,198.0,191.0,193.0,197.0,191.0,196.0,188.0,199.0,189.0,189.0,187.0,198.0,176.0,202.0,186.0,199.0,191.0,195.0,191.0,210.0,190.0,197.0,193.0,199.0,187.0,190.0,191.0,200.0,185.0,193.0,193.0,187.0,188.0,190.0,192.0,185.0,190.0,184. ...

# %%
df.corr().values
# Out:
# array([[ 1.        , -0.23505287,  0.65618134,  0.59510982],
#        [-0.23505287,  1.        , -0.58385122, -0.47191562],
#        [ 0.65618134, -0.58385122,  1.        ,  0.87120177],
#        [ 0.59510982, -0.47191562,  0.87120177,  1.        ]])

# %% [markdown]
# ## Histograms

# %%
# Pandas plot histogram

df.hist(column='body_mass_g', bins=10, grid=True, rwidth=.9, color='tab:blue',
        alpha=0.5, fill='blue');

# %%
# Pyplot histogram

#plt.hist(df['body_mass_g']);
plt.hist(df['culmen_length_mm'])
plt.hist(df['body_mass_g'], color = 'tab:blue' );
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-734474da9b7a> in <cell line: 4>()
#       2
#       3 #plt.hist(df['body_mass_g']);
# ----> 4 plt.hist(df['culmen_length_mm'])
#       5 plt.hist(df['body_mass_g'], color = 'tab:blue' );
#
# NameError: name 'plt' is not defined

# %%
# Seaborn histogram

sns.histplot(df['body_mass_g']);

# %%
# Plotly Express

fig = px.histogram(df, x="body_mass_g")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="27458685-1f74-4eea-8051-5926c8551f85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27458685-1f74-4eea-8051-5926c8551f85")) {                    Plotly.newPlot(                        "27458685-1f74-4eea-8051-5926c8551f85",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"body_mass_g=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3750.0,3800.0,3250.0,null,3450.0,3650.0,3625.0,4675.0,3475.0,4250.0,3300.0,3700.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3400.0,3600.0,3800.0,3950.0,3800.0,3800.0,3550.0,3200.0,3150.0,3950.0,3250.0,3900.0,3300.0,3900.0,3325.0,4150.0,3950.0,3550.0,3300.0,4650.0,3150.0,3900.0,3100.0,4400.0,3000.0,4600.0,3425.0,2975.0,3450.0,4150.0,3500.0,4300.0,3450.0,4050.0,2900.0,3700.0,3550.0,3800.0,2850.0,3750.0,3150.0,4400.0,3600.0,4050.0,2850.0,3950.0,3350.0,4100.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,3350.0,3550.0,3800.0,3500.0,3950.0,3600.0,3550.0,4300.0,3400.0,4450.0,3300.0,4300.0,3700.0,4350.0,2900.0,4100.0,3725.0,4725.0,3075.0,4250.0,2925.0,3550.0,3750.0,3900.0,3175.0,4775.0,3825.0,4600.0,3200.0,4275.0,3900.0,4075.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0,3500.0,4475.0,3425.0,3900.0,3175.0,3975.0,3400.0,4250.0,3400.0,3475.0,3050.0,3725.0,3000.0,3650.0,4250.0,3475.0,3450.0,3750.0,3700.0,4000.0,3500.0,3900.0,3650.0,3525.0,3725.0,3950.0,3250.0,3750.0,4150.0,3700.0,3800.0,3775.0,3700.0,4050.0,3575.0,4050.0,3300.0,3700.0,3450.0,4400.0,3600.0,3400.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,3700.0,4550.0,3200.0,4300.0,3350.0,4100.0,3600.0,3900.0,3850.0,4800.0,2700.0,4500.0,3950.0,3650.0,3550.0,3500.0,3675.0,4450.0,3400.0,4300.0,3250.0,3675.0,3325.0,3950.0,3600.0,4050.0,3350.0,3450.0,3250.0,4050.0,3800.0,3525.0,3950.0,3650.0,3650.0,4000.0,3400.0,3775.0,4100.0,3775.0,4500.0,5700.0,4450.0,5700.0,5400.0,4550.0,4800.0,5200.0,4400.0,5150.0,4650.0,5550.0,4650.0,5850.0,4200.0,5850.0,4150.0,6300.0,4800.0,5350.0,5700.0,5000.0,4400.0,5050.0,5000.0,5100.0,4100.0,5650.0,4600.0,5550.0,5250.0,4700.0,5050.0,6050.0,5150.0,5400.0,4950.0,5250.0,4350.0,5350.0,3950.0,5700.0,4300.0,4750.0,5550.0,4900.0,4200.0,5400.0,5100.0,5300.0,4850.0,5300.0,4400.0,5000.0,4900.0,5050.0,4300.0,5000.0,4450.0,5550.0,4200.0,5300.0,4400.0,5650.0,4700.0,5700.0,4650.0,5800.0,4700.0,5550.0,4750.0,5000.0,5100.0,5200.0,4700.0,5800.0,4600.0,6000.0,4750.0,5950.0,4625.0,5450.0,4725.0,5350.0,4750.0,5600.0,4600.0,5300.0,4875.0,5550.0,4950.0,5400.0,4750.0,5650.0,4850.0,5200.0,4925.0,4875.0,4625.0,5250.0,4850.0,5600.0,4975.0,5500.0,4725.0,5500.0,4700.0,5500.0,4575.0,5500.0,5000.0,5950.0,4650.0,5500.0,4375.0,5850.0,4875.0,6000.0,4925.0,null,4850.0,5750.0,5200.0,5400.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar": ...

# %%
# Plotnine histogram
from plotnine import *

(
    ggplot(df, aes(x='body_mass_g'))
    + geom_histogram(bins=10, alpha=0.5, fill='blue') # specify the number of bins
)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/layer.py:360: PlotnineWarning:
#
# stat_bin : Removed 2 rows containing non-finite values.
# <ggplot: (8793285625017)>

# %% [markdown]
# ## Bar Plots

# %%
# Using Pandas plot bar

df['species'].value_counts().plot(kind='bar', color = 'tab:blue');

# %%
# Using Pandas plot horizontal bars (barh)

df['species'].value_counts().plot(kind='barh', color='tab:olive');

# %%
df.groupby('species').flipper_length_mm.mean().plot(kind='bar');

# %%
df.groupby('species').body_mass_g.mean().plot.bar();

# %%
df1[['species','island', 'sex','body_mass_g']].groupby(['island','species','sex']).mean().plot.bar();

# %%
# Using Seaborn barplot

sns.barplot(x=df['species'],y=df['flipper_length_mm']).set(title="Flipper Length");

# %% [markdown]
# ## KDE Plots

# %%
df_length = df[['culmen_length_mm', 'culmen_depth_mm',	'flipper_length_mm']]
df_length.plot.kde()

# %%
sns.FacetGrid(df, hue="species", height=6,) \
   .map(sns.kdeplot, "flipper_length_mm", shade=True) \
   .add_legend();

# %% [markdown]
# ## Boxplot

# %%
# Using Pandas boxplot
boxplot = df.boxplot(column=['culmen_length_mm', 'culmen_depth_mm',	'flipper_length_mm'])

# %%
# Using Pandas boxplot

boxplot = df.groupby('species').boxplot(column=['flipper_length_mm'], color='blue', subplots=False)
plt.title('Penguins characteristics')
plt.ylabel('flipper_length_mm');
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Using Seaborn

sns.boxplot(x="species", y="flipper_length_mm", data=df)

# %%
# Seaborn

sns.boxplot(x="species",y="body_mass_g", data=df).set(title="Penguin characteristics");

# %%
ax= sns.boxplot(x=df1.sex, y=df['culmen_length_mm'],orient="v")

# %%
sns.catplot(x='species',y='culmen_length_mm',data=df1,kind='box', col='island');

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %% [markdown]
# ## Violinplots

# %%
# Seaborn violin plot

sns.violinplot(x='species', y='body_mass_g', hue='island', data=df1);

# %%
# Seaborn violin plot

sns.violinplot(data=df1, x='species', y='body_mass_g', hue='sex',
               split=True, inner="quart", linewidth=1)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Add gap

sns.violinplot(data=df1, x='species', y='body_mass_g', hue='sex',
               split=True, inner="quart", linewidth=1, gap=0.1)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Plotly Express Violin Plot

fig = px.violin(df, y="body_mass_g", x="species", color="island", box=True,
          hover_data=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f6a7f066-2b26-4877-bb65-e2fce521165a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6a7f066-2b26-4877-bb65-e2fce521165a")) {                    Plotly.newPlot(                        "f6a7f066-2b26-4877-bb65-e2fce521165a",                        [{"alignmentgroup":"True","box":{"visible":true},"customdata":[["Torgersen",39.1,18.7,181.0,"MALE"],["Torgersen",39.5,17.4,186.0,"FEMALE"],["Torgersen",40.3,18.0,195.0,"FEMALE"],["Torgersen",null,null,null,null],["Torgersen",36.7,19.3,193.0,"FEMALE"],["Torgersen",39.3,20.6,190.0,"MALE"],["Torgersen",38.9,17.8,181.0,"FEMALE"],["Torgersen",39.2,19.6,195.0,"MALE"],["Torgersen",34.1,18.1,193.0,null],["Torgersen",42.0,20.2,190.0,null],["Torgersen",37.8,17.1,186.0,null],["Torgersen",37.8,17.3,180.0,null],["Torgersen",41.1,17.6,182.0,"FEMALE"],["Torgersen",38.6,21.2,191.0,"MALE"],["Torgersen",34.6,21.1,198.0,"MALE"],["Torgersen",36.6,17.8,185.0,"FEMALE"],["Torgersen",38.7,19.0,195.0,"FEMALE"],["Torgersen",42.5,20.7,197.0,"MALE"],["Torgersen",34.4,18.4,184.0,"FEMALE"],["Torgersen",46.0,21.5,194.0,"MALE"],["Torgersen",35.9,16.6,190.0,"FEMALE"],["Torgersen",41.8,19.4,198.0,"MALE"],["Torgersen",33.5,19.0,190.0,"FEMALE"],["Torgersen",39.7,18.4,190.0,"MALE"],["Torgersen",39.6,17.2,196.0,"FEMALE"],["Torgersen",45.8,18.9,197.0,"MALE"],["Torgersen",35.5,17.5,190.0,"FEMALE"],["Torgersen",42.8,18.5,195.0,"MALE"],["Torgersen",40.9,16.8,191.0,"FEMALE"],["Torgersen",37.2,19.4,184.0,"MALE"],["Torgersen",36.2,16.1,187.0,"FEMALE"],["Torgersen",42.1,19.1,195.0,"MALE"],["Torgersen",34.6,17.2,189.0,"FEMALE"],["Torgersen",42.9,17.6,196.0,"MALE"],["Torgersen",36.7,18.8,187.0,"FEMALE"],["Torgersen",35.1,19.4,193.0,"MALE"],["Torgersen",38.6,17.0,188.0,"FEMALE"],["Torgersen",37.3,20.5,199.0,"MALE"],["Torgersen",35.7,17.0,189.0,"FEMALE"],["Torgersen",41.1,18.6,189.0,"MALE"],["Torgersen",36.2,17.2,187.0,"FEMALE"],["Torgersen",37.7,19.8,198.0,"MALE"],["Torgersen",40.2,17.0,176.0,"FEMALE"],["Torgersen",41.4,18.5,202.0,"MALE"],["Torgersen",35.2,15.9,186.0,"FEMALE"],["Torgersen",40.6,19.0,199.0,"MALE"],["Torgersen",38.8,17.6,191.0,"FEMALE"],["Torgersen",41.5,18.3,195.0,"MALE"],["Torgersen",39.0,17.1,191.0,"FEMALE"],["Torgersen",44.1,18.0,210.0,"MALE"],["Torgersen",38.5,17.9,190.0,"FEMALE"],["Torgersen",43.1,19.2,197.0,"MALE"]],"hovertemplate":"island=%{customdata[0]}<br>species=%{x}<br>body_mass_g=%{y}<br>culmen_length_mm=%{customdata[1]}<br>culmen_depth_mm=%{customdata[2]}<br>flipper_length_mm=%{customdata[3]}<br>sex=%{customdata[4]}<extra></extra>","legendgroup":"Torgersen","marker":{"color":"#636efa"},"name":"Torgersen","offsetgroup":"Torgersen","orientation":"v","scalegroup":"True","showlegend":true,"x":["Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie","Adelie"],"x0":" ","xaxis":"x","y":[3750.0,3800.0,3250.0,null,3450.0,3650.0,3625.0,4675.0,3475.0,4250.0,3300.0,3700.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0],"y0":" ","yaxis":"y","type":"violin"},{"alignmentgroup":"True","box":{"visible":true},"customdata":[["Biscoe",37.8,18.3,174.0,"FEMALE"],["Biscoe",37.7,18.7,180.0,"MALE"],["Biscoe",35 ...

# %% [markdown]
# ## Scatter plot

# %%
# Pandas Plot

dfA = df[df['species'] == 'Adelie'].dropna()
dfC = df[df['species'] == 'Chinstrap'].dropna()
dfG = df[df['species'] == 'Gentoo'].dropna()

ax = dfA.plot.scatter(x='body_mass_g', y='flipper_length_mm',
                      c='tab:green', label='Adelie',
                      xlabel='Body mass (g)', ylabel='Flipper length (mm)',
                      title='Pandas Scatter Plot', figsize=(12, 8))
dfC.plot.scatter(x='body_mass_g', y='flipper_length_mm', ax=ax, c='tab:orange',
                 label='Chinstrap')
dfG.plot.scatter(x='body_mass_g', y='flipper_length_mm', ax=ax, c='tab:purple',
                 label='GentooA')

plt.show()

# %%
# Matplotlib.Pyplot

# Define plotting variables
x = df.body_mass_g.values
y = df.flipper_length_mm.values
Pspecies = df.species.values
Pspecies_ = np.unique(Pspecies) # Keep only unique species values
Pcolors = ["#1B9E77", "#D95F02", "#7570B3"]
Pmarkers = ["o", "^", "s"] # circle, triangle, square

fig, ax = plt.subplots(figsize=(9,6))

for species, color, marker in zip(Pspecies_, Pcolors, Pmarkers):
    idxs = np.where(Pspecies == species)
    # No legend will be generated if we don't pass label=species
    ax.scatter(
        x[idxs], y[idxs], label=species,
        s= 30, color=color, marker=marker, alpha=0.7)

plt.xlabel('Body mass (g)')
plt.ylabel('Flipper length (mm)')
plt.title('Matplotlib Pyplot Scatter Plot')
ax.legend();

# %%
# Seaborn

#define figure size
sns.set(rc={"figure.figsize":(12, 8)}) #width=12, height=8
sns.set_style("whitegrid")

sns.scatterplot(data=df, x="body_mass_g", y="flipper_length_mm", hue="species",
                style="island");

# %%
# Seaborn plot 1 (sns.lmplot)

sns.lmplot( x='body_mass_g', y='flipper_length_mm', data=df, fit_reg=False,
           hue='species', legend=False, markers=["o", "^", "s"], palette="Set2",
           height=6, aspect=1.5)
plt.xlabel('Body mass (g)')
plt.ylabel('Flipper length (mm)')
plt.title('Seaborn Scatter Plot')

# Move the legend to an empty part of the plot
plt.legend()

plt.show()

# %%
# Seaborn Plot 2 (sns.FacetGrid)

sns.FacetGrid(df, hue="species", height=8) \
   .map(plt.scatter, "body_mass_g", "flipper_length_mm") \
   .add_legend();

# %%
# Bokeh scatterplot

from bokeh.plotting import figure, show
from bokeh.sampledata.penguins import data
from bokeh.transform import factor_cmap, factor_mark

SPECIES = sorted(data.species.unique())
MARKERS = ['hex', 'circle_x', 'triangle']

p = figure(title = "Penguin size", background_fill_color="#fafafa")
p.xaxis.axis_label = 'Flipper Length (mm)'
p.yaxis.axis_label = 'Body Mass (g)'

p.scatter("flipper_length_mm", "body_mass_g", source=data,
          legend_group="species", fill_alpha=0.4, size=12,
          marker=factor_mark('species', MARKERS, SPECIES),
          color=factor_cmap('species', 'Category10_3', SPECIES))

p.legend.location = "top_left"
p.legend.title = "Species"

show(p)
# Out:
#   <div id="d6ef1eca-6c15-4586-808a-25e5c33fb55f" data-root-id="p1787" style="display: contents;"></div>

# %%
# Plotly Express (Interactive)

fig = px.scatter(df, x="body_mass_g", y="flipper_length_mm", color="species", symbol="species")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0cac52c8-5797-4bf7-b4b4-6c79498b9122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cac52c8-5797-4bf7-b4b4-6c79498b9122")) {                    Plotly.newPlot(                        "0cac52c8-5797-4bf7-b4b4-6c79498b9122",                        [{"hovertemplate":"species=Adelie<br>body_mass_g=%{x}<br>flipper_length_mm=%{y}<extra></extra>","legendgroup":"Adelie","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Adelie","orientation":"v","showlegend":true,"x":[3750.0,3800.0,3250.0,null,3450.0,3650.0,3625.0,4675.0,3475.0,4250.0,3300.0,3700.0,3200.0,3800.0,4400.0,3700.0,3450.0,4500.0,3325.0,4200.0,3400.0,3600.0,3800.0,3950.0,3800.0,3800.0,3550.0,3200.0,3150.0,3950.0,3250.0,3900.0,3300.0,3900.0,3325.0,4150.0,3950.0,3550.0,3300.0,4650.0,3150.0,3900.0,3100.0,4400.0,3000.0,4600.0,3425.0,2975.0,3450.0,4150.0,3500.0,4300.0,3450.0,4050.0,2900.0,3700.0,3550.0,3800.0,2850.0,3750.0,3150.0,4400.0,3600.0,4050.0,2850.0,3950.0,3350.0,4100.0,3050.0,4450.0,3600.0,3900.0,3550.0,4150.0,3700.0,4250.0,3700.0,3900.0,3550.0,4000.0,3200.0,4700.0,3800.0,4200.0,3350.0,3550.0,3800.0,3500.0,3950.0,3600.0,3550.0,4300.0,3400.0,4450.0,3300.0,4300.0,3700.0,4350.0,2900.0,4100.0,3725.0,4725.0,3075.0,4250.0,2925.0,3550.0,3750.0,3900.0,3175.0,4775.0,3825.0,4600.0,3200.0,4275.0,3900.0,4075.0,2900.0,3775.0,3350.0,3325.0,3150.0,3500.0,3450.0,3875.0,3050.0,4000.0,3275.0,4300.0,3050.0,4000.0,3325.0,3500.0,3500.0,4475.0,3425.0,3900.0,3175.0,3975.0,3400.0,4250.0,3400.0,3475.0,3050.0,3725.0,3000.0,3650.0,4250.0,3475.0,3450.0,3750.0,3700.0,4000.0],"xaxis":"x","y":[181.0,186.0,195.0,null,193.0,190.0,181.0,195.0,193.0,190.0,186.0,180.0,182.0,191.0,198.0,185.0,195.0,197.0,184.0,194.0,174.0,180.0,189.0,185.0,180.0,187.0,183.0,187.0,172.0,180.0,178.0,178.0,188.0,184.0,195.0,196.0,190.0,180.0,181.0,184.0,182.0,195.0,186.0,196.0,185.0,190.0,182.0,179.0,190.0,191.0,186.0,188.0,190.0,200.0,187.0,191.0,186.0,193.0,181.0,194.0,185.0,195.0,185.0,192.0,184.0,192.0,195.0,188.0,190.0,198.0,190.0,190.0,196.0,197.0,190.0,195.0,191.0,184.0,187.0,195.0,189.0,196.0,187.0,193.0,191.0,194.0,190.0,189.0,189.0,190.0,202.0,205.0,185.0,186.0,187.0,208.0,190.0,196.0,178.0,192.0,192.0,203.0,183.0,190.0,193.0,184.0,199.0,190.0,181.0,197.0,198.0,191.0,193.0,197.0,191.0,196.0,188.0,199.0,189.0,189.0,187.0,198.0,176.0,202.0,186.0,199.0,191.0,195.0,191.0,210.0,190.0,197.0,193.0,199.0,187.0,190.0,191.0,200.0,185.0,193.0,193.0,187.0,188.0,190.0,192.0,185.0,190.0,184.0,195.0,193.0,187.0,201.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=Chinstrap<br>body_mass_g=%{x}<br>flipper_length_mm=%{y}<extra></extra>","legendgroup":"Chinstrap","marker":{"color":"#EF553B","symbol":"diamond"},"mode":"markers","name":"Chinstrap","orientation":"v","showlegend":true,"x":[3500.0,3900.0,3650.0,3525.0,3725.0,3950.0,3250.0,3750.0,4150.0,3700.0,3800.0,3775.0,3700.0,4050.0,3575.0,4050.0,3300.0,3700.0,3450.0,4400.0,3600.0,3400.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,3700.0,4550.0,3200.0,4300.0,3350.0,4100.0,3600.0,3900.0,3850.0,4800.0,2700.0,4500.0,3950.0,3650.0,3550.0,3500.0,3675.0,4450.0,3400.0,4300.0,3250.0,3675.0,3325.0,3950.0,3600.0,4050.0,3350.0,3450.0,3250.0,4050.0,3800.0,3525.0,3950.0,3650.0,3650.0,4000.0,3400.0,3775.0,4100.0,3775.0],"xaxis":"x","y":[192.0,196.0,193.0,188.0,197.0,198.0,178.0,197.0,195.0,198.0,193.0,194.0,185.0,201.0,190.0,201.0,197.0,181.0,190.0,195.0,181.0,191.0,187.0,193.0,195.0,197.0,200.0,200.0,191.0,205.0,187.0,201.0,187.0,203.0,195.0,199.0,195.0,210.0,192.0,205.0,210.0,187.0,196.0,196.0,196.0,201.0,190.0,212.0,187.0,198.0,199.0,201.0,193.0,203.0,187.0,197.0,191.0,203.0,202.0,194.0,206.0,189.0,195.0,207.0,202.0,193.0,210.0,198.0],"yaxis":"y","type":"scatter"},{"hovertem ...

# %%
# Plotnine
from plotnine import *
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

(
  ggplot(df, aes(x='body_mass_g', y='flipper_length_mm', color='factor(species)'))
  + geom_point()
  + labs(x='Body mass (g)', y='Flipper length (mm)', title='Plotnine Scatter Plot')
)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/layer.py:452: PlotnineWarning:
#
# geom_point : Removed 2 rows containing missing values.
# <ggplot: (8793282910197)>

# %%
# Matplotlib pyplot (Example 2)

import matplotlib.patches

plt.figure(figsize=(10,8))

levels, categories = pd.factorize(df['species'])
colors = [plt.cm.tab10(i) for i in levels] # using the "tab10" colormap
handles = [matplotlib.patches.Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

plt.scatter(df['body_mass_g'], df['flipper_length_mm'], c=colors)
plt.gca().set(xlabel='mass (g)', ylabel='Flipper Length (mm)', title='Penguin Mass vs Flipper Length')
plt.legend(handles=handles, title='Species');

# %%
# body mass vs. flipper length

sns.set(style="ticks", color_codes=True)

g  = sns.FacetGrid(df, col="island", hue="species", height=8)
g = g.map(plt.scatter, "body_mass_g", "flipper_length_mm", edgecolor="w")
g = g.add_legend()

g.axes[0,0].set_xlabel('body mass (g)')
g.axes[0,1].set_ylabel('Flipper Length (mm)')

plt.close(2)
plt.show()

# %% [markdown]
# ### Scatter matrix plot / Pair plot

# %%
# Using Pandas plotting scatter_matrix
pd.plotting.scatter_matrix(df, alpha = 0.3, figsize = (14,8), diagonal = 'hist');

# %%
# Bokeh Scatter Plot Matrix

from itertools import product

from bokeh.io import show
from bokeh.layouts import gridplot
from bokeh.models import (BasicTicker, Circle, ColumnDataSource,
                          DataRange1d, Grid, LassoSelectTool, LinearAxis,
                          PanTool, Plot, ResetTool, WheelZoomTool)
from bokeh.sampledata.penguins import data
from bokeh.transform import factor_cmap

df = data.copy()
df["body_mass_kg"] = df["body_mass_g"] / 1000

SPECIES = sorted(df.species.unique())
ATTRS = ("bill_length_mm", "bill_depth_mm", "body_mass_kg")
N = len(ATTRS)

source = ColumnDataSource(data=df)

xdrs = [DataRange1d(bounds=None) for _ in range(N)]
ydrs = [DataRange1d(bounds=None) for _ in range(N)]

plots = []

for i, (y, x) in enumerate(product(ATTRS, reversed(ATTRS))):
    p = Plot(x_range=xdrs[i%N], y_range=ydrs[i//N],
             background_fill_color="#fafafa",
             border_fill_color="white", width=200, height=200, min_border=5)

    if i % N == 0:  # first column
        p.min_border_left = p.min_border + 4
        p.width += 40
        yaxis = LinearAxis(axis_label=y)
        yaxis.major_label_orientation = "vertical"
        p.add_layout(yaxis, "left")
        yticker = yaxis.ticker
    else:
        yticker = BasicTicker()
    p.add_layout(Grid(dimension=1, ticker=yticker))

    if i >= N*(N-1):  # last row
        p.min_border_bottom = p.min_border + 40
        p.height += 40
        xaxis = LinearAxis(axis_label=x)
        p.add_layout(xaxis, "below")
        xticker = xaxis.ticker
    else:
        xticker = BasicTicker()
    p.add_layout(Grid(dimension=0, ticker=xticker))

    circle = Circle(x=x, y=y, fill_alpha=0.6, size=5, line_color=None,
                    fill_color=factor_cmap('species', 'Category10_3', SPECIES))
    r = p.add_glyph(source, circle)
    p.x_range.renderers.append(r)
    p.y_range.renderers.append(r)

    # suppress the diagonal
    if (i%N) + (i//N) == N-1:
        r.visible = False
        p.grid.grid_line_color = None

    p.add_tools(PanTool(), WheelZoomTool(), ResetTool(), LassoSelectTool())

    plots.append(p)

show(gridplot(plots, ncols=N))
# Out:
#   <div id="aebb69f3-404a-4dc1-a7a5-44588b6c7dc0" data-root-id="p2070" style="display: contents;"></div>

# %%
sns.pairplot(df, hue='species', height=3);

# %%
sns.pairplot(df, hue="species", height=3, diag_kind="hist");
